# %% [markdown]
# ## Programming Assignment 2
# **Name - ** Akash B Dhasade
#
# **Roll No - ** TCS15B031
#
# Q.1) Filling in the dataset information -
#
# |S.NO| |1 |2 | 3 | 4 |5 | 6 | 7 | 8 | 9 |
# | :---- |:---- |:---- |:---- |:---- |:---- |:---- |:---- |:---- |
# ||**Name of Dataset**| Image segmentation dataset| Ionosphere dataset | Iris dataset | Letter recognition dataset | Liver disorder dataset| Solar flare Dataset| SPECT Heart Disease| Wisconsin Breast Cancer Dataset (Diagnostic) |Wisconsin Breast Cancer Dataset (Prognostic) |
# |1 | Feature vector dimension | (19,1)| (34,1)| (4,1) | (16,1) | (6,1) | | (44,1)| (30,1) | (32,1) |
# |2 | No of classes | 7 | 2 | 3 | 26 | 2 | | 2| 2| 2 |
# | 3| Prior prob for each class |0.142857142857143 | good : 0.64  bad : 0.36|0.33||1: 0.42 , 2: 0.58 | | 0: 0.21, 1: 0.79| Begnign: 0.63, Malignant: 0.37| |
# | 4| Mean vector dimension | (19,1)| (34,1) | (4,1) | (16,1) | (6,1)| |(44, 1) | (30,1) | (32,1) |
# | 5| Covariance Matrix Dim | (19,19) | (19,19) | (4,4) | (16,16) | (6,6) | | (44,44)| (30,30) | (32,32)|
#
#
# *(Class labels and id's are not included as a part of feature vector in the above table)*

# %% [markdown]
# Q.2) **Selected Dataset** - Wisconsin Breast Cancer dataset (Diagnostic)
#
# **Selected feature** - radius
#
# Plotting radius for **begnign** tumors: $p(x_{1}/\omega_{1})$
#
# ![image](https://user-images.githubusercontent.com/24961068/36589784-88f07732-18b2-11e8-8c19-ba1149965044.png)

# %% [markdown]
# Plotting radius for **malignant** tumors: $p(x_{1}/\omega_{2})$
#
# ![image](https://user-images.githubusercontent.com/24961068/36589821-a87d0ad4-18b2-11e8-84f5-6147b771eaa1.png)

# %% [markdown]
# *(Note - There are only two classes in this dataset)*

# %% [markdown]
# Let  $X =\begin{bmatrix}
# x_{1}\\
# x_{2}
# \end{bmatrix}
# $
#
# $\omega_{2}$ = malignant, $\omega_{1}$ = begnign
#
# $x_{1}$ = radius, $x_{2}$ = texture

# %% [markdown]
# Plotting radius and texture for **malignant** tumors: $p(X/\omega_{2})$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Plotting radius and texture for **begnign** tumors: $p(X/\omega_{1})$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Q.3) Covariance matrices obtained are as follows:
#
# **Case1:** $\Sigma =
# \begin{bmatrix}
# 28.08653648 && -2.67460878 \\
# -2.67460878 &&  52.73731709 \\
# \end{bmatrix}
# $
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Case 2:**
#
# $\Sigma_{1} =
# \begin{bmatrix}
# 3.94017237 && 3.94017237 \\
# 3.94017237 && 3.94017237 \\
# \end{bmatrix}
# $
#
# $\Sigma_{2} =
# \begin{bmatrix}
#  4.08459469 &&-2.80244651 \\
# -2.80244651  &&3.62351897\\
# \end{bmatrix}
# $
#
#
# $\Sigma_{2} =
# \begin{bmatrix}
#  4.43757656 && 0.18823133\\
#  0.18823133 && 1.05164408\\
#  \end{bmatrix}
# $
#
# *(I got $\Sigma_{1}$ as above and it's determinant is 0. Hence I couldn't
# plot the contours)*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **On using the Bayesian classification library offered by `sklearn`, plot I got:**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Case 3:**
#
# $\Sigma_{1} =
# \begin{bmatrix}
# 3.94017237 && 0 \\
# 0 && 3.94017237 \\
# \end{bmatrix}
# $
#
# $\Sigma_{2} =
# \begin{bmatrix}
#  4.08459469 && 0 \\
# 0  &&3.62351897\\
# \end{bmatrix}
# $
#
#
# $\Sigma_{2} =
# \begin{bmatrix}
#  4.43757656 && 0\\
#  0 && 1.05164408\\
#  \end{bmatrix}
# $
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Note** - I tried plotting eigen vectors but couldn't find exact matlab equivalent functions. I could somehow plot the eigen vectors but couldn't shift them to correct origins. The vectors I obtained are shown below.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# I couldn't obtain surface plot correctly, some plots I obtained are shown below.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# I just scattered the points belonging to different classes on a scatter plot. The plot obtained is as follows:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q.3) b) Plot for **Case 1:**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Plot for **Case 2:**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Plot for **Case 3:**
#
# ![image.png](attachment:image.png)
